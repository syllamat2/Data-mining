# %%
from sklearn.model_selection import train_test_split 
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error, max_error
from sklearn import svm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Current__2021-2022__Assessment_Roll.csv")
df.head(10)
# Out:
# /Users/makhtarsylla/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (82,83) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                   SBL  TAX DISTRICT        PRINT KEY  FRONT  DEPTH  \
# 0    0785000008017900        147009     78.50-8-17.9  65.00   30.0
# 1    6660000065023000        147001     666.00-65-23   0.00    0.0
# 2    5550000091007000        147001      555.00-91-7   0.00    0.0
# 3    1236900001016000        147013      123.69-1-16  30.00  109.0
# 4  100390000103200000        147006  100.39-1-32./83   1.00  215.0
# 5    0907700003012000        147005       90.77-3-12  54.28  117.0
# 6    1225100002013200        147013    122.51-2-13.2  15.00  173.0
# 7    1112400002032000        147003      111.24-2-32  30.00  100.0
# 8    1113900005003000        147003       111.39-5-3  29.82    0.0
# ...

# %% [markdown]
# ## Data Cleaning-

# %%
df = df.drop(columns=["PRINT KEY", "PREVIOUS PROPERTY CLASS", "OWNER2", "PREVIOUS OWNER", "MAIL1", "MAIL2", "MAIL3", "MAIL4", "HOUSE NUMBER", "STREET", "ZIP CODE (4-DIGIT)", "DEED BOOK", "DEED PAGE", "DEED DATE", "YEAR BUILT"])

# %%
df
# Out:
#                       SBL  TAX DISTRICT  FRONT  DEPTH  \
# 0        0785000008017900        147009  65.00   30.0
# 1        6660000065023000        147001   0.00    0.0
# 2        5550000091007000        147001   0.00    0.0
# 3        1236900001016000        147013  30.00  109.0
# 4      100390000103200000        147006   1.00  215.0
# ...                   ...           ...    ...    ...
# 93648    1005200005026000        147005  45.00   63.0
# 93649    0776700001020000        147008  23.33  130.0
# 93650    1017800002047000        147004  30.00  100.0
# 93651    0902500003047000        147010  30.00  110.0
# 93652    1003500002003000        147005  35.00  105.0
#
#               PROP CLASS DESCRIPTION                     OWNER1  \
# 0            RESIDENTIAL VACANT LAND  CHANDRASEKHARAN PRAVEEN K
# 1                          TELEPHONE               CENTURY LINK
# 2      TELEPHONE - SPECIAL FRANCHISE             TVC ALBANY INC
# ...

# %% [markdown]
# ### Nandita suggested to Continue to modelling and skip the cleaning- (more on data cleaning)
